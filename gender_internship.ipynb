# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample Data
data = {
    'Age': [22, 25, 47, 35, 46, 55, 43, 36, 21, 20, 45, 50, 23, 29, 31, 38, 40, 44, 48, 49, 28, 27, 30, 34, 32, 33, 37, 39, 41, 42],
    'Gender': ['F', 'M', 'F', 'M', 'F', 'F', 'M', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'F', 'M', 'M', 'F', 'F', 'M', 'M', 'F', 'F', 'M', 'M', 'F', 'F', 'M', 'M']
}

df = pd.DataFrame(data)

# Plotting the distribution of ages
plt.figure(figsize=(10, 6))
plt.hist(df['Age'], bins=10, edgecolor='black')
plt.title('Distribution of Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
